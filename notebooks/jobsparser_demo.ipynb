# %%
from jobsparser import ParseJobDesc , ParseResume , TextCleaner, TextUtils

# %%
a = TextCleaner()

b = TextUtils()

print(b.generate_unique_id())

a.clean_text("I am a good 34513412341234###@#!@$")
# Out:
# 16d6c624-2955-4602-8f1c-405ff9058446
# 'I am a good 1234###@#!@$'

# %%
## Testing the job parser
resumeProcessor = ParseResume(
    TextUtils().read_single_pdf("../data/raw/extracted/data/data/ENGINEERING/10030015.pdf")
)
jobDescriptionProcessor = ParseJobDesc(
    TextUtils().read_single_pdf("../data/external/JobDescription/job_desc_front_end_engineer.pdf")
)

# %%
resumeProcessor.get_JSON()
# Out:
# {'unique_id': 'a18bbe1f-6b8a-4eff-9e33-d112b396398c',
# ...

# %%
jobDescriptionProcessor.get_JSON()
# Out:
# {'unique_id': '94ff48ba-be2f-43ee-a25b-becbbecb21ae',
# ...
